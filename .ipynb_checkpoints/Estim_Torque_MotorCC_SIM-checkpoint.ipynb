# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import pandas as pd
import seaborn as sns

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
n = 100 # numero de pontos

# tensão lida
vt = np.linspace(0,127,n)
erroVt = np.random.rand(1,n) #Variação da leitura
Vt = vt+erroVt # Tensão de leitura

# corrente lida
ia = np.linspace(0,5,n)
erroia = 0.1*(np.random.rand(1,n)) #Variação da leitura
Ia = ia+erroia # Corrente de leitura

# velocidade lida
w = np.linspace(0,188.4,n)
errow = (np.random.rand(1,n)) #Variação da leitura
W = w+errow

# Resistencia da armadura
Ra = 0.1

# Tensão da Armadura
Ea = Vt-Ra*Ia

# KPhi
KPhi = Ea/W

# Torque
T = (Ea*Ia)/W


m = np.matrix([Vt[0], Ia[0], W[0], Ea[0], KPhi[0], T[0]])
m = m.T

# %%
# Cria um dataframe com os dados 
df = pd.DataFrame(m, columns = ['Vt', 'Ia', 'W', 'Ea', 'KPhi', 'T'])
df.head()
# Out:
#          Vt        Ia         W        Ea      KPhi         T
# 0  0.336035  0.004454  0.981617  0.335590  0.341874  0.001523
# 1  1.359010  0.130836  2.013891  1.345926  0.668321  0.087441
# 2  3.089590  0.103462  3.966866  3.079244  0.776241  0.080312
# 3  4.792885  0.235274  6.528585  4.769357  0.730535  0.171876
# 4  5.150646  0.255311  8.282176  5.125115  0.618813  0.157990

# %%
# Figuras 3D
plt.rcParams['figure.figsize'] = (10,8)

ax = plt.axes(projection='3d') # Cria as dimensões dos 3 eixos
ax.scatter3D(Vt,Ia,W, s = 100)
ax.set_xlabel('Tensão de terminal Vt')
ax.set_ylabel('Corrente de armadura Ia')
ax.set_zlabel('Velocidade em rad/s')
ax.view_init(0,215)

# %%
dataset = df.copy()
train_dataset = dataset.sample(frac=0.8,random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
train_dataset.tail()
# Out:
#             Vt        Ia           W          Ea      KPhi
# 69   89.375301  3.568657  131.999191   89.018435  0.674386
# 20   25.870759  1.103219   38.140582   25.760438  0.675408
# 94  121.579926  4.748526  179.751629  121.105073  0.673736
# 72   92.801544  3.659468  137.855480   92.435597  0.670525
# 77   99.232259  3.889941  146.694803   98.843265  0.673802

# %%
test_dataset.head()
# Out:
#            Vt        Ia          W         Ea      KPhi         T
# 9   11.553547  0.547375  17.142571  11.498810  0.670775  0.367165
# 12  15.610709  0.659773  23.472282  15.544732  0.662259  0.436941
# 21  27.845954  1.151923  40.101742  27.730762  0.691510  0.796566
# 25  32.987461  1.353418  48.438663  32.852119  0.678221  0.917917
# 36  46.250526  1.881440  68.907034  46.062382  0.668471  1.257689

# %%
sns.pairplot(train_dataset[["Vt","Ia", "W", "Ea","KPhi","T"]], diag_kind="kde")

# %%
train_stats = train_dataset.describe()
train_stats.pop("T")
train_stats = train_stats.transpose()
train_stats
# Out:
#       count       mean        std       min        25%        50%         75%  \
# Vt     80.0  62.677109  38.188039  0.336035  29.490181  64.083903   95.520803
# Ia     80.0   2.498176   1.500088  0.004454   1.184854   2.556824    3.829025
# W      80.0  92.699084  56.592887  0.981617  43.716863  95.134109  141.779328
# Ea     80.0  62.427292  38.038063  0.335590  29.371696  63.828220   95.137901
# KPhi   80.0   0.671951   0.040773  0.341874   0.670835   0.673453    0.676205
#
#              max
# Vt    127.666442
# Ia      5.051111
# W     189.118921
# Ea    127.161330
# KPhi    0.776241

# %%
train_labels = train_dataset.pop('T')
test_labels = test_dataset.pop('T')

# %%
train_labels.head()
# Out:
# 26    0.923686
# 86    2.941632
# 2     0.080312
# 55    1.886525
# 75    2.578401
# Name: T, dtype: float64

# %%
test_labels.head()
# Out:
# 9     0.367165
# 12    0.436941
# 21    0.796566
# 25    0.917917
# 36    1.257689
# Name: T, dtype: float64

# %%
def norm(x):
  return (x - train_stats['mean']) / train_stats['std']
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)

# %%
normed_train_data.head()
# Out:
#           Vt        Ia         W        Ea      KPhi
# 26 -0.766896 -0.749018 -0.763578 -0.766966  0.000617
# 86  1.264708  1.255499  1.271235  1.264744 -0.014242
# 2  -1.560371 -1.596382 -1.567904 -1.560228  2.557806
# 55  0.217163  0.204227  0.218919  0.217214  0.017626
# 75  0.895764  0.887863  0.894949  0.895794  0.030719

# %%
normed_test_data.head()
# Out:
#           Vt        Ia         W        Ea      KPhi
# 9  -1.338732 -1.300458 -1.335088 -1.338882 -0.028835
# 12 -1.232491 -1.225530 -1.223242 -1.232517 -0.237698
# 21 -0.912096 -0.897450 -0.929398 -0.912153  0.479710
# 25 -0.777459 -0.763127 -0.782085 -0.777515  0.153783
# 36 -0.430150 -0.411133 -0.420407 -0.430225 -0.085335

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(50, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(25, activation='relu'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 50)                300
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                1275
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 1,601
# Trainable params: 1,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = build_model()

class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 1000
# O parâmetro patience é o quantidade de epochs para checar as melhoras
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)

history = model.fit(normed_train_data, train_labels, epochs=EPOCHS,
                    validation_split = 0.2, verbose=0, callbacks=[early_stop, PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# .

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [Torque]')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,2])
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [$Torque^2$]')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,5])
  plt.legend()
  plt.show()
   


plot_history(history)

# %%
loss, mae, mse = model.evaluate(normed_test_data, test_labels, verbose=2)

print("Testing set Mean Abs Error: {:5.2f} Torque".format(mae))
# Out:
# 1/1 - 0s - loss: 0.0011 - mae: 0.0269 - mse: 0.0011
# Testing set Mean Abs Error:  0.03 Torque

# %%
test_predictions = model.predict(normed_test_data).flatten()

# %%
test_predictions-test_labels
# Out:
# 9     0.029206
# 12    0.064222
# 21   -0.002864
# 25    0.013694
# 36    0.004736
# 37    0.042683
# 39    0.008885
# 44   -0.032008
# 46    0.013694
# 47    0.038646
# 58   -0.027505
# 64    0.028013
# 65    0.005624
# 67    0.007299
# 70   -0.012708
# 81    0.058628
# 83    0.018959
# 87    0.040022
# 88   -0.036002
# 96    0.052513
# Name: T, dtype: float64

# %%
m2 = np.matrix([Vt[0], Ia[0], W[0], Ea[0], KPhi[0]])
m2 = m2.T

# %%
df2 = pd.DataFrame(m2, columns = ['Vt', 'Ia', 'W', 'Ea', 'KPhi'])
df2.head()
# Out:
#          Vt        Ia         W        Ea      KPhi
# 0  0.336035  0.004454  0.981617  0.335590  0.341874
# 1  1.359010  0.130836  2.013891  1.345926  0.668321
# 2  3.089590  0.103462  3.966866  3.079244  0.776241
# 3  4.792885  0.235274  6.528585  4.769357  0.730535
# 4  5.150646  0.255311  8.282176  5.125115  0.618813

# %%
normdf = norm(df2)
print(normdf)
# Out:
#           Vt        Ia         W        Ea      KPhi
# 0  -1.632476 -1.662384 -1.620654 -1.632357 -8.095407
# 1  -1.605689 -1.578134 -1.602413 -1.605796 -0.089015
# 2  -1.560371 -1.596382 -1.567904 -1.560228  2.557806
# 3  -1.515768 -1.508513 -1.522638 -1.515796  1.436818
# 4  -1.506400 -1.495156 -1.491652 -1.506443 -1.303259
# ..       ...       ...       ...       ...       ...
# 95  1.568265  1.563509  1.574106  1.568283 -0.009042
# 96  1.596117  1.578569  1.604745  1.596185 -0.022828
# 97  1.621902  1.646530  1.624007  1.621803  0.009458
# 98  1.675803  1.671934  1.660331  1.675817  0.097812
# 99  1.701824  1.701857  1.703745  1.701823  0.010728
#
# [100 rows x 5 columns]

# %%
test_predictions = model.predict(normdf).flatten()

# %%
td = np.array(test_predictions)

# %%
plt.plot(td,'r')
plt.plot(T[0],'b')

# %%
medidas = np.matrix([127.5, 5, 8, 127.1, 30])

df3 = pd.DataFrame(medidas, columns = ['Vt', 'Ia', 'W', 'Ea', 'KPhi'])

MedNorm = norm(df3)
print(MedNorm)


torque_pred = model.predict(MedNorm).flatten()
print(torque_pred)
# Out:
#          Vt        Ia         W       Ea        KPhi
# 0  1.697466  1.667785 -1.496638  1.70021  719.295393
# [111.46484]
